# %% [markdown]
# # Example of Loss Adapted Plasticity:

# %%
from loss_adapted_plasticity import LossAdaptedPlasticity

# %%
loss_reweighting = LossAdaptedPlasticity()
# Out:
# LossAdaptedPlasticity(
#   (source_order): ParameterDict()
# )

# %%
loss_reweighting

# %%
loss_reweighting.source_unreliability_
# Out:
# {}
